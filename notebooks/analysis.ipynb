# %% [markdown]
# # Cold-Start Recommendation System Analysis
#
# This notebook provides an in-depth analysis of the cold-start recommendation system, including data exploration, model training, evaluation, and visualization of results.

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import json
import warnings
warnings.filterwarnings('ignore')

# Add src to path
sys.path.append(str(Path.cwd().parent / "src"))

from cold_start.data import DataLoader, DataGenerator
from cold_start.models import ContentBasedRecommender, HybridRecommender, ColdStartRecommender
from cold_start.evaluation import Evaluator
from cold_start.utils import set_seed, load_config

# Set random seed for reproducibility
set_seed(42)

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
